# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
bar = (
    Bar().add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
    .add_yaxis("商家B", [15, 6, 45, 20, 35, 66])
    .set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="37c3619a1cea4fd79ef070709dff4d60" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_37c3619a1cea4fd79ef070709dff4d60 = echarts.init(
#                     document.getElementById('37c3619a1cea4fd79ef070709dff4d60'), 'white', {renderer: 'canvas'});
#                 var option_37c3619a1cea4fd79ef070709dff4d60 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

bar = Bar()
bar.add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
bar.add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
bar.set_global_opts(
    title_opts=opts.TitleOpts(title="货品销售情况",subtitle = "A和B公司"),
    toolbox_opts = opts.ToolboxOpts(is_show = True)
)
bar.set_series_opts(
    label_opts=opts.LabelOpts(position = "right"))
# bar.reversal_axis()
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="266d3482418648d7baebad009d22c442" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_266d3482418648d7baebad009d22c442 = echarts.init(
#                     document.getElementById('266d3482418648d7baebad009d22c442'), 'white', {renderer: 'canvas'});
#                 var option_266d3482418648d7baebad009d22c442 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Page,Pie

L1=['教授','副教授','讲师','助教','其他']
num = [20,30,10,12,8]

c = Pie()
c.add("",[list(z) for z in zip(L1,num)])
c.set_global_opts(title_opts=opts.TitleOpts(title="Pie-职称类比比例"))
c.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}:{c}"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b9e283faf44e43658cc268209972671b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b9e283faf44e43658cc268209972671b = echarts.init(
#                     document.getElementById('b9e283faf44e43658cc268209972671b'), 'white', {renderer: 'canvas'});
#                 var option_b9e283faf44e43658cc268209972671b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
wd = ['教授','副教授','讲师','助教','其他']
num = [20,30,10,12,8]
c = Pie()
c.add("",[list(z) for z in zip(wd, num)],
      radius = ["40%", "75%"])
# 圆环的粗细和大小
c.set_global_opts(
    title_opts=opts.TitleOpts(title="Pie-Radius"),legend_opts=opts.LegendOpts( orient="vertical", pos_top="5%", pos_left="2%" ))
c .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="658c2db72a8f41ae9e9bc7cee31a9dd1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_658c2db72a8f41ae9e9bc7cee31a9dd1 = echarts.init(
#                     document.getElementById('658c2db72a8f41ae9e9bc7cee31a9dd1'), 'white', {renderer: 'canvas'});
#                 var option_658c2db72a8f41ae9e9bc7cee31a9dd1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...
