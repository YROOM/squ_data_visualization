# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# 1.链式调用
# bar = (Bar().add.add)
# bar = Bar()
# bar.add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣","高跟鞋", "袜子"])
# bar.add_yaxis("商家A", [114, 55, 27, 101, 125, 27,105])
# 2. pyecharts整体绘图逻辑
## (1) 初始化具体类型图表  bar= (Bar())
## (2) 添加数据及其配置项
## (3) 绘图  bar.render()
bar=(Bar()
     .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣","高跟鞋", "袜子"])
     .add_yaxis("商家A", [114, 55, 27, 101, 125, 27,105])
     .set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况",))
     )
# bar.render_notebook()
bar.render("bar2.html")
# Out:
# 'D:\\备课\\sj\\data_visualization\\week_5\\bar2.html'

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# 内置主题类型可查看 pyecharts.globals.ThemeType
from pyecharts.globals import ThemeType

bar = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.HALLOWEEN))
    .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
    .add_yaxis("商家B", [15, 6, 45, 20, 35, 66])
    .set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
)
bar.render("bar3.html")
# Out:
# 'D:\\备课\\sj\\data_visualization\\week_5\\bar3.html'

# %%
bar = (Bar()
       .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
       .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
       .add_yaxis("商家B", [15, 25, 16, 55, 48, 8])
       .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
       )
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3f54b1e445714d438702f9e61034e54a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3f54b1e445714d438702f9e61034e54a = echarts.init(
#                     document.getElementById('3f54b1e445714d438702f9e61034e54a'), 'white', {renderer: 'canvas'});
#                 var option_3f54b1e445714d438702f9e61034e54a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Page,Pie

c=Pie() # 声明所需要的图例
L1=['教授','副教授','讲师','助教','其他']
num=[20,30,10,12,8]
# L1 num 一一对应 [教授：20，副教授:30]
c.add("",[list(z) for z in zip(L1,num)])
c.set_global_opts(title_opts=opts.TitleOpts(title="Pie-职称类别比例"))
c.set_series_opts(labelbel_opts=opts.LabelOpts(formatter="{b}:{c}"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b6467a7e20244ff6a5108f7290c11a7f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b6467a7e20244ff6a5108f7290c11a7f = echarts.init(
#                     document.getElementById('b6467a7e20244ff6a5108f7290c11a7f'), 'white', {renderer: 'canvas'});
#                 var option_b6467a7e20244ff6a5108f7290c11a7f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
from pyecharts.charts import Funnel
from pyecharts import options as opta
data=[45,86,39,52,68]
labels=['电脑','手机','彩电','冰箱','洗衣机']
wf=Funnel()
wf.add('电器销量图',[list(z) for z in zip(labels,data)])
wf.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="693c7f50c6ff4b96aefa646d39b9b93a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_693c7f50c6ff4b96aefa646d39b9b93a = echarts.init(
#                     document.getElementById('693c7f50c6ff4b96aefa646d39b9b93a'), 'white', {renderer: 'canvas'});
#                 var option_693c7f50c6ff4b96aefa646d39b9b93a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Scatter

c=Scatter()
week=["周一","周二","周三","周四","周五","周六","周日"]
c.add_xaxis(week)
c.add_yaxis("商家A",[81,65,48,32,67,92,87])
c.set_global_opts(title_opts=opts.TitleOpts(title="Scatter-一周的销售额（万元）"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6fc0dcaf4c2843e7ac9abaaa258fbb8b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6fc0dcaf4c2843e7ac9abaaa258fbb8b = echarts.init(
#                     document.getElementById('6fc0dcaf4c2843e7ac9abaaa258fbb8b'), 'white', {renderer: 'canvas'});
#                 var option_6fc0dcaf4c2843e7ac9abaaa258fbb8b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...
