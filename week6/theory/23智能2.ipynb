# %%
import datetime
import pandas as pd
import numpy as np
date = datetime.date(2019, 6, 1)
print(date)
print(date.year,date.month,date.day)

# %%
time = datetime.time(10,20,15)
print(time)
print(time.hour,time.minute,time.second)

# %%
now=datetime.datetime(2019,12,12)
birth=datetime.datetime(2016,5,1)
delta=now-birth
print(delta)
newdatetime=birth+datetime.timedelta(120)
print(newdatetime)

# %%
w_value='2019-6-23'
print(datetime.datetime.strptime('2019-06-23','%Y-%m-%d'))
datetrs=['7/19/1976','8/1/1976']
[datetime.datetime.strptime(x,'%m/%d/%Y')for x in datetrs]
# Out:
# 2019-06-23 00:00:00
# [datetime.datetime(1976, 7, 19, 0, 0), datetime.datetime(1976, 8, 1, 0, 0)]

# %%
w_dates= [datetime.datetime(2018,5,15),datetime.datetime(2018,6,15),
          datetime.datetime(2019,5,18),datetime.datetime(2019,5,25)]
s=pd.Series(np.arange(4),index=w_dates)
s
# Out:
# 2018-05-15    0
# 2018-06-15    1
# 2019-05-18    2
# 2019-05-25    3
# dtype: int64

# %%
datetimes=pd.date_range('2018-12-29','2019-01-03')
datetimes
# Out:
# DatetimeIndex(['2018-12-29', '2018-12-30', '2018-12-31', '2019-01-01',
#                '2019-01-02', '2019-01-03'],
#               dtype='datetime64[ns]', freq='D')

# %%
datetimes=pd.date_range('2018-12-29',periods=10)
datetimes
# Out:
# DatetimeIndex(['2018-12-29', '2018-12-30', '2018-12-31', '2019-01-01',
#                '2019-01-02', '2019-01-03', '2019-01-04', '2019-01-05',
#                '2019-01-06', '2019-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
wdate = pd.Series(np.random.randn(4),index = pd.date_range('2019/1/1',periods=4,freq = 'M'))
print(wdate)
# Out:
# 2019-01-31    1.693591
# 2019-02-28    0.852323
# 2019-03-31   -1.001988
# 2019-04-30   -0.946842
# Freq: ME, dtype: float64
# C:\Users\24138\AppData\Local\Temp\ipykernel_13472\1390560811.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   wdate = pd.Series(np.random.randn(4),index = pd.date_range('2019/1/1',periods=4,freq = 'M'))

# %%
wdate.shift(2)
# Out:
# 2019-01-31         NaN
# 2019-02-28         NaN
# 2019-03-31    1.693591
# 2019-04-30    0.852323
# Freq: ME, dtype: float64
