# %%
import datetime

import numpy as np
import pandas as pd
from scipy.signal import periodogram

date = datetime.date(2019,6,1)
print(date)
print(date.year,date.month,date.day)

# %%
time=datetime.time(10,20,15)
print(time)
print(time.hour,time.minute,time.second)

# %%
now = datetime.datetime(2019,12,12)
birth = datetime.datetime(2016,5,1)
delta = now - birth
print(delta)
newdatetime=birth+datetime.timedelta(120)
print(newdatetime)

# %%
from datetime import datetime
stamp = datetime(2019,6,4)
print(str( stamp))

# %%
w_value='2019-6-23'
print(datetime.strptime('2019-6-23','%Y-%m-%d'))
datestrs=['7/19/1976','8/1/1976']
[datetime.strptime(x,'%m/%d/%Y') for x in datestrs]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 w_value='2019-6-23'
# ----> 2 print(datetime.strptime('2019-6-23','%Y-%m-%d'))
#       3 datestrs=['7/19/1976','8/1/1976']
#       4 [datetime.strptime(x,'%m/%d/%Y') for x in datestrs]
#
# NameError: name 'datetime' is not defined

# %%
import datetime

import numpy as np
import pandas as pd
w_dates = [
    datetime.datetime(2018,5,15),
    datetime.datetime(2018,6,15),
    datetime.datetime(2019,5,18),
   datetime.datetime(2019,5,25)]
s = pd.Series(np.arange(4),index= w_dates)
print(s)
# Out:
# 2018-05-15    0
# 2018-06-15    1
# 2019-05-18    2
# 2019-05-25    3
# dtype: int64

# %%
index = pd.date_range(start = '2019-5-28',periods = 6)
index
# Out:
# DatetimeIndex(['2019-05-28', '2019-05-29', '2019-05-30', '2019-05-31',
#                '2019-06-01', '2019-06-02'],
#               dtype='datetime64[ns]', freq='D')

# %%
wdate=pd.Series(np.random.randn(4),index=pd.date_range('2019/1/1',periods=4,freq='ME'))
print(wdate)
wdate.shift(2)
# Out:
# 2019-01-31   -0.324308
# 2019-02-28   -0.783162
# 2019-03-31   -0.892641
# 2019-04-30    0.771802
# Freq: ME, dtype: float64
# 2019-01-31         NaN
# 2019-02-28         NaN
# 2019-03-31   -0.324308
# 2019-04-30   -0.783162
# Freq: ME, dtype: float64

# %%
w = pd.Period('2019-1-1',freq='A-DEC')

print(w)
# Out:
# 2019
# C:\Users\24138\AppData\Local\Temp\ipykernel_15000\522744928.py:1: FutureWarning: 'A-DEC' is deprecated and will be removed in a future version, please use 'Y-DEC' instead.
#   w = pd.Period('2019-1-1',freq='A-DEC')
